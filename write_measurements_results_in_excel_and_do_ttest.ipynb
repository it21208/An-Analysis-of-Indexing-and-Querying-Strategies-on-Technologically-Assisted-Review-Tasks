# %%
# author = Alexandros
import csv
import glob
import os
import numpy as np
import pandas as pd
import re
from scipy.stats import ttest_ind
from scipy.stats import ttest_rel 
import matplotlib.pyplot as plt
#================================================================

lst_b_sweep = ['b0.0','b0.1','b0.2','b0.3','b0.4','b0.5','b0.6','b0.7','b0.8','b0.9','b1.0']
lst_k_sweep = ['k1.0','k1.2','k1.4','k1.6','k1.8','k2.0']
# i need to make two loops that iterate over all the pairs of the different indexing techniques
#control_run1 = 'bm25_0.75_pubmed_1_b0.9_tar.query.res_trec_eval_q_measurements'
#control_run2 = 'bm25_0.75_pubmed_2_b0.9_tar.title.query.res_trec_eval_q_measurements'
txt_files = []
list_of_runs = []
#measurements_results
#measurements_results_q_bm25_b_0.75_k_sweep_Feb_11_2017 
# measurements_results_bm25_b_sweep_k_1.2_February_12_2017
#measurements_results_bm25_b_0.75_k_sweep_February_12_2017
#/home/alexandros/netbeans-8.2/NetBeansProjects/lucene4ir-master/data/pubmed/measurements_results_from_testing_pubmed5_with_different_tokenisers_for_the_5_different_query_variations_ksweep_20022018
for file in os.listdir("/home/alexandros/netbeans-8.2/NetBeansProjects/lucene4ir-master/data/pubmed/measurements_results"):
    list_of_runs.append(file)
    txt_files.append("/home/alexandros/netbeans-8.2/NetBeansProjects/lucene4ir-master/data/pubmed/measurements_results/"+file)
    #header.append(file)

list_of_lines = []
contents = [''] * len(txt_files)
for i, txt_file in enumerate(txt_files):
    with open(txt_file) as f:
        contents[i] = txt_file.rsplit('/', 1)[-1]+'\n'
        list_of_lines.append(txt_file.rsplit('/', 1)[-1]+'\n')
        for line in f.readlines():
            #print(line)
            contents[i] += line
            line2 = ' '.join(line.split())
            #print(line2)
            line3 = line2.split(' ')
            #print(line3)
            list_of_lines.append(line3)    

wanted_list_of_lines = []            
for i in list_of_lines:
    #print(i)
    if "bm25" in i:
        wanted_list_of_lines.append(i)
    if i[0] in ['map','P_10','P_20','P_30','iprec_at_recall_0.10','iprec_at_recall_0.20','iprec_at_recall_0.30']:
        if i[1] == 'all':
            #print(i)
            wanted_list_of_lines.append(i)  
                                        
for i in wanted_list_of_lines:
    print(i)
'''
#===========================================================================================================
#===========================================================================================================  

for control_run1 in list_of_runs:
    #print(control_run1)
    #query_schemes = ['tar.query.res','tar.title.query.res','tar.query.title.query.res','tar.query2.res','tar.query.title.query2.res','tar.query3.res','tar.query4.res','tar.query5.res','tar.query.title.query3.res','tar.query.title.query4.res','tar.query.title.query5.res']
    query_schemes = ['tar.query.res','tar.title.query.res','tar.query.title.query.res']
    if '_pubmed_1' in control_run1:        
        for i in query_schemes:
            if i in control_run1:
                tmp_query_scheme = i
        #query_schemes.remove(tmp_query_scheme)
        for j in lst_k_sweep:
            if j in control_run1:
                tmp_param = j
        #print(tmp_param)
        for control_run2 in list_of_runs:
            if '_pubmed_1' not in control_run2:
                #print(control_run2)
                if tmp_query_scheme in control_run2:
                    if tmp_param in control_run2:
                #for i in query_schemes: 
                #    if i in control_run2:
                        if control_run1 != control_run2:
                            #txt_files = []
                            #header = ['','','']
                            #list_of_runs = []
                            #for file in os.listdir("/home/alexandros/netbeans-8.2/NetBeansProjects/lucene4ir-master/data/pubmed/measurements_results"):
                            #    list_of_runs.append(file)
                            #    txt_files.append("/home/alexandros/netbeans-8.2/NetBeansProjects/lucene4ir-master/data/pubmed/measurements_results/"+file)
                                #header.append(file)
                            list_of_lines = []
                            contents = [''] * len(txt_files)
                            for i, txt_file in enumerate(txt_files):
                                with open(txt_file) as f:
                                    contents[i] = txt_file.rsplit('/', 1)[-1]+'\n'
                                    list_of_lines.append(txt_file.rsplit('/', 1)[-1]+'\n')
                                    for line in f.readlines():
                                        contents[i] += line
                                        line2 = ' '.join(line.split())
                                        line3 = line2.split(' ')
                                        list_of_lines.append(line3)
#================================================================
#================================================================
                            wanted_list_of_lines = []            
                            for i in list_of_lines:
                                #print(i)
                                # ['map','P_10','P_20','P_30','iprec_at_recall_0.10','iprec_at_recall_0.20','iprec_at_recall_0.30']
                                
                                if (("bm25" in i) or (i[0] in ['map'])):
                                    if (i[1] != 'all'):
                                        wanted_list_of_lines.append(i)
                                
                                #if "bm25" in i:
                                #    wanted_list_of_lines.append(i)
                                #if i[0] in ['map','P_10','P_20','P_30','iprec_at_recall_0.10','iprec_at_recall_0.20','iprec_at_recall_0.30']:
                                #    if i[1] == 'all':
                                        #print(i)
                                #        wanted_list_of_lines.append(i)  
                                        
#================================================================            
#================================================================
                            # map measurement 
                            list_map_sweep = []        
                            for i in wanted_list_of_lines:
                                #print(i)
                                if ("bm25" in i):
                                    list_map_sweep.append('')
                                    list_map_sweep.append(i)
                                if (i[0] == 'map'):
                                    #list_map_sweep.append([i[1],i[2]])
                                    #print(i[2])
                                    list_map_sweep.append(i[2])
#================================================================
                            # P_10 measurement 
                            list_P_10_sweep = []        
                            for i in wanted_list_of_lines:
                                if ("bm25" in i):
                                    list_P_10_sweep.append('')
                                    list_P_10_sweep.append(i)
                                if (i[0] == 'P_10'):
                                    #list_P_10_sweep.append([i[1],i[2]])
                                    list_P_10_sweep.append(i[2])
#================================================================    
                            # P_20 measurement 
                            list_P_20_sweep = []        
                            for i in wanted_list_of_lines:
                                if ("bm25" in i):
                                    list_P_20_sweep.append('')
                                    list_P_20_sweep.append(i)
                                if (i[0] == 'P_20'):
                                    #list_P_20_sweep.append([i[1],i[2]])
                                    list_P_20_sweep.append(i[2])
#================================================================       
                            # P_30 measurement 
                            list_P_30_sweep = []        
                            for i in wanted_list_of_lines:
                                if ("bm25" in i):
                                    list_P_30_sweep.append('')
                                    list_P_30_sweep.append(i)
                                if (i[0] == 'P_30'):
                                    #list_P_30_sweep.append([i[1],i[2]])
                                    list_P_30_sweep.append(i[2])
#================================================================
                            # iprec_at_recall_0.10 measurement 
                            list_iprec_at_recall_0_10_sweep = []        
                            for i in wanted_list_of_lines:
                                if ("bm25" in i):
                                    list_iprec_at_recall_0_10_sweep.append('')
                                    list_iprec_at_recall_0_10_sweep.append(i)
                                if (i[0] == 'iprec_at_recall_0.10'):
                                    #list_iprec_at_recall_0_10_sweep.append([i[1],i[2]])
                                    list_iprec_at_recall_0_10_sweep.append(i[2])
#================================================================
                            # iprec_at_recall_0.20 measurement 
                            list_iprec_at_recall_0_20_sweep = []        
                            for i in wanted_list_of_lines:
                                if ("bm25" in i):
                                    list_iprec_at_recall_0_20_sweep.append('')
                                    list_iprec_at_recall_0_20_sweep.append(i)
                                if (i[0] == 'iprec_at_recall_0.20'):
                                    #list_iprec_at_recall_0_20_sweep.append([i[1],i[2]])
                                    list_iprec_at_recall_0_20_sweep.append(i[2])
#================================================================
                            # iprec_at_recall_0.30 measurement 
                            list_iprec_at_recall_0_30_sweep = []        
                            for i in wanted_list_of_lines:
                                if ("bm25" in i):
                                    list_iprec_at_recall_0_30_sweep.append('')
                                    list_iprec_at_recall_0_30_sweep.append(i)
                                if (i[0] == 'iprec_at_recall_0.30'):
                                    #list_iprec_at_recall_0_30_sweep.append([i[1],i[2]])
                                    list_iprec_at_recall_0_30_sweep.append(i[2]) 

                            #for i in list_map_sweep:
                            #    print(i)
                            _list_map_sweep = ['']*(len(txt_files)+1)
                            counter = 0
                            flag = 1
                            flag2 = 0
                            for i in list_map_sweep:
                                #print(i)
                                if ("bm25" in i):
                                    counter = counter + 1
                                if i in ' ':
                                    flag2 = flag2 + 1
                                else:
                                    _list_map_sweep[counter] += (i+',')
                                    flag2 = flag2 - 1
                                if flag == 51: # flag == 51
                                    flag = 0
                                if flag2 == 2:
                                    break
                        
                            _list_map_sweep.pop(0)    
                            #print(len(_list_map_sweep))       
                            for idx, obj in enumerate(_list_map_sweep):
                                #print(obj)
                                new_obj = obj.replace('\n', '').replace(',', ' ')
                                new_obj2 = new_obj.split()
                                _list_map_sweep[idx] = new_obj2
    
                            for idx, obj in enumerate(_list_map_sweep):
                                #print(obj)
                                tmp = obj[0]
                                obj.pop(0)
                                obj = list(map(float, obj))
                                _list_map_sweep[idx] = [tmp, obj] 

                            # run different t-tests     
                            for i in _list_map_sweep:
                                #print(i)
                                if i[0] == control_run1:
                                    run1 = i[0]
                                    values1 = i[1]    
                                if i[0] == control_run2:
                                    run2 = i[0]
                                    values2 = i[1]
                            #print(([run1]*50)+([run2]*50))
                            #print('\n')
                            #print(values1+values2)
                            data = {'Category': ([run1]*50)+([run2]*50),'values': values1+values2}
                            #print(data)
                            #data = {'Category': ([run1])+([run2]),'values': values1+values2}
                            print(data)
                            my_data = pd.DataFrame(data, dtype=float) # my_data = pd.DataFrame(data, dtype=float) #my_data.groupby('Category').mean() 
                            _run1 = my_data[my_data['Category']== run1] 
                            _run2 = my_data[my_data['Category']== run2] 
                            print('Statistical test for MAP measurement of the following runs:')
                            #print(run1)
                            #print(run2)
                            #ttest_ind(_run1['values'], _run2['values'])
                            #print(ttest_ind(_run1['values'], _run2['values']))
                            ttest_rel(_run1['values'], _run2['values'])
                            print(ttest_rel(_run1['values'], _run2['values']))
                            print('\n')
# (what it returns) >> (1.4927289925706944, 0.16970867501294376)
# it returns a tuple with the t-statistic & the p-value
#================================================================    

                            _list_P_10_sweep = ['']*(len(txt_files)+1)  
                            counter = 0
                            flag = 1
                            flag2 = 0
                            for i in list_P_10_sweep:
                                if ("bm25" in i):
                                    counter = counter + 1
                                if i in ' ':
                                    flag2 = flag2 + 1
                                else:
                                    _list_P_10_sweep[counter] += (i+',')
                                    flag2 = flag2 - 1
                                if flag == 51:
                                    flag = 0
                                if flag2 == 2:
                                    break
    
                            _list_P_10_sweep.pop(0)    
                            #print(len(_list_map_sweep))       
                            for idx, obj in enumerate(_list_P_10_sweep):
                                new_obj = obj.replace('\n', '').replace(',', ' ')
                                new_obj2 = new_obj.split()
                                _list_P_10_sweep[idx] = new_obj2

                            for idx, obj in enumerate(_list_P_10_sweep):
                                tmp = obj[0]
                                obj.pop(0)
                                obj = list(map(float, obj))
                                _list_P_10_sweep[idx] = [tmp, obj] 

                            # run different t-tests     
                            for i in _list_P_10_sweep:
                                if i[0] == control_run1:
                                    run1 = i[0]
                                    values1 = i[1]    
                                if i[0] == control_run2:
                                    run2 = i[0]
                                    values2 = i[1]

                            data = {'Category': ([run1]*50)+([run2]*50), 'values': values1+values2}
                            #data = {'Category': ([run1])+([run2]),'values': values1+values2}
                            my_data = pd.DataFrame(data, dtype=float) # my_data = pd.DataFrame(data, dtype=float) #my_data.groupby('Category').mean()
                            _run1 = my_data[my_data['Category']== run1] 
                            _run2 = my_data[my_data['Category']== run2] 
                            print('Statistical test for P_10 measurement of the following runs:')
                            print(run1)
                            print(run2)
                            #ttest_ind(_run1['values'], _run2['values'])
                            #print(ttest_ind(_run1['values'], _run2['values']))
                            ttest_rel(_run1['values'], _run2['values'])
                            print(ttest_rel(_run1['values'], _run2['values']))
                            print('\n')   
#================================================================    

                            _list_P_20_sweep = ['']*(len(txt_files)+1)
                            counter = 0
                            flag = 1
                            flag2 = 0
                            for i in list_P_20_sweep:
                                if ("bm25" in i):
                                    counter = counter + 1
                                if i in ' ':
                                    flag2 = flag2 + 1
                                else:
                                    _list_P_20_sweep[counter] += (i+',')
                                    flag2 = flag2 - 1
                                if flag == 51:
                                    flag = 0
                                if flag2 == 2:
                                    break
    
                            _list_P_20_sweep.pop(0)    
                            #print(len(_list_map_sweep))       
                            for idx, obj in enumerate(_list_P_20_sweep):
                                new_obj = obj.replace('\n', '').replace(',', ' ')
                                new_obj2 = new_obj.split()
                                _list_P_20_sweep[idx] = new_obj2

                            for idx, obj in enumerate(_list_P_20_sweep):
                                tmp = obj[0]
                                obj.pop(0)
                                obj = list(map(float, obj))
                                _list_P_20_sweep[idx] = [tmp, obj] 

                            # run different t-tests   
                            for i in _list_P_20_sweep:
                                if i[0] == control_run1:
                                    run1 = i[0]
                                    values1 = i[1]    
                                if i[0] == control_run2:
                                    run2 = i[0]
                                    values2 = i[1]   

                            #print(([run1]*50)+([run2]*50))
                            #print('\n')
                            #print(values1+values2)
                            data = {'Category': ([run1]*50)+([run2]*50), 'values': values1+values2}
                            #data = {'Category': ([run1])+([run2]),'values': values1+values2}
                            my_data = pd.DataFrame(data, dtype=float) # my_data = pd.DataFrame(data, dtype=float) #my_data.groupby('Category').mean()   
                            _run1 = my_data[my_data['Category']== run1] 
                            _run2 = my_data[my_data['Category']== run2] 
                            print('Statistical test for P_20 measurement of the following runs:')
                            print(run1)
                            print(run2)
                            #ttest_ind(_run1['values'], _run2['values'])
                            #print(ttest_ind(_run1['values'], _run2['values']))
                            ttest_rel(_run1['values'], _run2['values'])
                            print(ttest_rel(_run1['values'], _run2['values']))
                            print('\n')
#================================================================        

                            _list_P_30_sweep = ['']*(len(txt_files)+1)
                            counter = 0
                            flag = 1
                            flag2 = 0
                            for i in list_P_30_sweep:
                                if  ("bm25" in i):
                                    counter = counter + 1
                                if i in ' ':
                                    flag2 = flag2 + 1
                                else:
                                    _list_P_30_sweep[counter] += (i+',')
                                    flag2 = flag2 - 1
                                if flag == 51:
                                    flag = 0
                                if flag2 == 2:
                                    break
    
                            _list_P_30_sweep.pop(0)    
                            #print(len(_list_map_sweep))       
                            for idx, obj in enumerate(_list_P_30_sweep):
                                new_obj = obj.replace('\n', '').replace(',', ' ')
                                new_obj2 = new_obj.split()
                                _list_P_30_sweep[idx] = new_obj2

                            for idx, obj in enumerate(_list_P_30_sweep):
                                tmp = obj[0]
                                obj.pop(0)
                                obj = list(map(float, obj))
                                _list_P_30_sweep[idx] = [tmp, obj] 
    
                            # run different t-tests     
                            for i in _list_P_30_sweep:
                                if  i[0] == control_run1:
                                    run1 = i[0]
                                    values1 = i[1]    
                                if i[0] == control_run2:
                                    run2 = i[0]
                                    values2 = i[1]

                            data = {'Category': ([run1]*50)+([run2]*50),'values': values1+values2}
                            #data = {'Category': ([run1])+([run2]),'values': values1+values2}
                            my_data = pd.DataFrame(data, dtype=float) # my_data = pd.DataFrame(data, dtype=float) #my_data.groupby('Category').mean() 
                            _run1 = my_data[my_data['Category']== run1] 
                            _run2 = my_data[my_data['Category']== run2] 
                            print('Statistical test for P_30 measurement of the following runs:')
                            print(run1)
                            print(run2)
                            #ttest_ind(_run1['values'], _run2['values'])
                            #print(ttest_ind(_run1['values'], _run2['values']))
                            ttest_rel(_run1['values'], _run2['values'])
                            print(ttest_rel(_run1['values'], _run2['values']))
                            print('\n')
#================================================================       

                            _list_iprec_at_recall_0_10_sweep = ['']*(len(txt_files)+1)
                            counter = 0
                            flag = 1
                            flag2 = 0
                            for i in list_iprec_at_recall_0_10_sweep:
                                if  ("bm25" in i):
                                    counter = counter + 1
                                if i in ' ':
                                    flag2 = flag2 + 1
                                else:
                                    _list_iprec_at_recall_0_10_sweep[counter] += (i+',')
                                    flag2 = flag2 - 1
                                if flag ==  51:
                                    flag = 0
                                if flag2 == 2:
                                    break
    
                            _list_iprec_at_recall_0_10_sweep.pop(0)    
                            #print(len(_list_map_sweep))       
                            for idx, obj in enumerate(_list_iprec_at_recall_0_10_sweep):
                                new_obj = obj.replace('\n', '').replace(',', ' ')
                                new_obj2 = new_obj.split()
                                _list_iprec_at_recall_0_10_sweep[idx] = new_obj2

                            for idx, obj in enumerate(_list_iprec_at_recall_0_10_sweep):
                                tmp = obj[0]
                                obj.pop(0)
                                obj = list(map(float, obj))
                                _list_iprec_at_recall_0_10_sweep[idx] = [tmp, obj] 

                            # run different t-tests     
                            for i in _list_iprec_at_recall_0_10_sweep:
                                if i[0] == control_run1:
                                    run1 = i[0]
                                    values1 = i[1]    
                                if i[0] == control_run2:
                                    run2 = i[0]
                                    values2 = i[1]

                            data = {'Category': ([run1]*50)+([run2]*50),'values': values1+values2}
                            #data = {'Category': ([run1])+([run2]),'values': values1+values2}
                            my_data = pd.DataFrame(data, dtype=float) # my_data = pd.DataFrame(data, dtype=float) - #my_data.groupby('Category').mean()
                            _run1 = my_data[my_data['Category']== run1]
                            _run2 = my_data[my_data['Category']== run2]
                            print('Statistical test for IRP at recall 0.10 measurement of the following runs:')
                            print(run1)
                            print(run2)
                            #ttest_ind(_run1['values'], _run2['values'])
                            #print(ttest_ind(_run1['values'], _run2['values']))
                            ttest_rel(_run1['values'], _run2['values'])
                            print(ttest_rel(_run1['values'], _run2['values']))
                            print('\n')
#================================================================      

                            _list_iprec_at_recall_0_20_sweep = ['']*(len(txt_files)+1)
                            counter = 0
                            flag = 1
                            flag2 = 0
                            for i in list_iprec_at_recall_0_20_sweep:
                                if ("bm25" in i):
                                    counter = counter + 1
                                if i in ' ':
                                    flag2 = flag2 + 1
                                else:
                                    _list_iprec_at_recall_0_20_sweep[counter] += (i+',')
                                    flag2 = flag2 - 1
                                if flag == 51:
                                    flag = 0
                                if flag2 == 2:
                                    break
    
                            _list_iprec_at_recall_0_20_sweep.pop(0)    
                            #print(len(_list_map_sweep))       
                            for idx, obj in enumerate(_list_iprec_at_recall_0_20_sweep):
                                new_obj = obj.replace('\n', '').replace(',', ' ')
                                new_obj2 = new_obj.split()
                                _list_iprec_at_recall_0_20_sweep[idx] = new_obj2

                            for idx, obj in enumerate(_list_iprec_at_recall_0_20_sweep):
                                tmp = obj[0]
                                obj.pop(0)
                                obj = list(map(float, obj))
                                _list_iprec_at_recall_0_20_sweep[idx] = [tmp, obj] 

                            # run different t-tests     
                            for i in _list_iprec_at_recall_0_20_sweep:
                                if i[0] == control_run1:
                                    run1 = i[0]
                                    values1 = i[1]    
                                if i[0] == control_run2:
                                    run2 = i[0]
                                    values2 = i[1]

                            data = {'Category': ([run1]*50)+([run2]*50),'values': values1+values2}
                            #data = {'Category': ([run1])+([run2]),'values': values1+values2}
                            my_data = pd.DataFrame(data, dtype=float) # my_data = pd.DataFrame(data, dtype=float) 
                            #my_data.groupby('Category').mean()
                            #print(my_data)  
                            _run1 = my_data[my_data['Category']== run1] 
                            _run2 = my_data[my_data['Category']== run2] 
                            print('Statistical test for IRP at recall 0.20 measurement of the following runs:')
                            print(run1)
                            print(run2)
                            #ttest_ind(_run1['values'], _run2['values'])
                            #print(ttest_ind(_run1['values'], _run2['values']))
                            ttest_rel(_run1['values'], _run2['values'])
                            print(ttest_rel(_run1['values'], _run2['values']))
                            print('\n')
#================================================================    

                            _list_iprec_at_recall_0_30_sweep = ['']*(len(txt_files)+1)
                            counter = 0
                            flag = 1
                            flag2 = 0
                            for i in list_iprec_at_recall_0_30_sweep:
                                if ("bm25" in i):
                                    counter = counter + 1
                                if i in ' ':
                                    flag2 = flag2 + 1
                                else:
                                    _list_iprec_at_recall_0_30_sweep[counter] += (i+',')
                                    flag2 = flag2 - 1
                                if flag == 51:
                                    flag = 0
                                if flag2 == 2:
                                    break
    
                            _list_iprec_at_recall_0_30_sweep.pop(0)    
                            #print(len(_list_map_sweep))       
                            for idx, obj in enumerate(_list_iprec_at_recall_0_30_sweep):
                                new_obj = obj.replace('\n', '').replace(',', ' ')
                                new_obj2 = new_obj.split()
                                _list_iprec_at_recall_0_30_sweep[idx] = new_obj2

                            for idx, obj in enumerate(_list_iprec_at_recall_0_30_sweep):
                                tmp = obj[0]
                                obj.pop(0)
                                obj = list(map(float, obj))
                                _list_iprec_at_recall_0_30_sweep[idx] = [tmp, obj] 

                            # run different t-tests     
                            for i in _list_iprec_at_recall_0_30_sweep:
                                if i[0] == control_run1:
                                    run1 = i[0]
                                    values1 = i[1]    
                                if i[0] == control_run2:
                                    run2 = i[0]
                                    values2 = i[1]
        
                            data = {'Category': ([run1]*50)+([run2]*50),'values': values1+values2}
                            #data = {'Category': ([run1])+([run2]),'values': values1+values2}
                            my_data = pd.DataFrame(data, dtype=float) # my_data = pd.DataFrame(data, dtype=float) 
                            #my_data.groupby('Category').mean()
                            #print(my_data)  
                            _run1 = my_data[my_data['Category']== run1] 
                            _run2 = my_data[my_data['Category']== run2] 
                            print('Statistical test for IRP at recall 0.30 measurement of the following runs:')
                            print(run1)
                            print(run2)
                            #ttest_ind(_run1['values'], _run2['values'])
                            #print(ttest_ind(_run1['values'], _run2['values']))
                            ttest_rel(_run1['values'], _run2['values'])
                            print(ttest_rel(_run1['values'], _run2['values']))
                            print('------------------------------------------------------')
                            print('\n')   
'''
#print(contents2)
#np.savetxt("/home/alexandros/netbeans-8.2/NetBeansProjects/lucene4ir-master/data/pubmed/measurements_results_csv/excel_results2.csv", contents2, delimiter=",", fmt='%s', header = ','.join(header))
# measurements_results_csv_q_from_17032018
#np.savetxt("/home/alexandros/netbeans-8.2/NetBeansProjects/lucene4ir-master/data/pubmed/measurements_results_csv/excel_results.csv", contents, delimiter=",", fmt='%s')
#np.savetxt("/home/alexandros/netbeans-8.2/NetBeansProjects/lucene4ir-master/data/pubmed/measurements_results_csv/excel_results.csv", wanted_list_of_lines, delimiter=",", fmt='%s')

print('Done')
# Out:
# bm25_b0.75_pubmed_3_k1.6_tar.query.res_trec_eval_measurements
#
# ['map', 'all', '0.0751']
# ['iprec_at_recall_0.10', 'all', '0.2267']
# ['iprec_at_recall_0.20', 'all', '0.1424']
# ['iprec_at_recall_0.30', 'all', '0.0964']
# ['P_10', 'all', '0.2286']
# ['P_20', 'all', '0.2167']
# ['P_30', 'all', '0.2032']
# bm25_b0.75_pubmed_5_k1.6_tar.query.title.query.res_trec_eval_measurements
#
# ['map', 'all', '0.1025']
# ['iprec_at_recall_0.10', 'all', '0.3044']
# ['iprec_at_recall_0.20', 'all', '0.1874']
# ['iprec_at_recall_0.30', 'all', '0.1324']
# ['P_10', 'all', '0.2738']
# ['P_20', 'all', '0.2583']
# ['P_30', 'all', '0.2413']
# bm25_b0.75_pubmed_4_k1.0_tar.title.query.res_trec_eval_measurements
#
# ['map', 'all', '0.1141']
# ['iprec_at_recall_0.10', 'all', '0.2879']
# ['iprec_at_recall_0.20', 'all', '0.2071']
# ['iprec_at_recall_0.30', 'all', '0.1491']
# ['P_10', 'all', '0.2833']
# ['P_20', 'all', '0.2714']
# ['P_30', 'all', '0.2627']
# ...
